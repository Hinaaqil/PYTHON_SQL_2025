# %% [markdown]
# Data Structures
# lists mutable []
# tuples immutable ()
# dictionaries mutable {}
# sets

# %% [markdown]
# Lists [] ---- mutable

# %%
#list function- list() --
my_list=[5,'python',3.14,True,'class']
print(my_list)
# Out:
# [5, 'python', 3.14, True, 'class']

# %%
#addition in list
my_list = my_list + ['maham']
print(my_list)
# Out:
# [5, 'python', 3.14, True, 'class', 'maham']

# %%
type(my_list)
# Out:
# list

# %%
#length function
len(my_list)
# Out:
# 6

# %%
#indexing fetch items- indexing starts with 0
my_list[2]
# Out:
# 3.14

# %%
my_list[-1]
# Out:
# 'maham'

# %%
#modify list items
my_list
# Out:
# [5, 'python', 3.14, True, 'class', 'maham']

# %%
my_list[0]=3

# %%
my_list  #it directly modified item at idex#0 bcz lists are mutable
# Out:
# [3, 'python', 3.14, True, 'class', 'maham']

# %%
#slicing 
my_list[0:2]
# Out:
# [3, 'python']

# %%
my_list[1:]
# Out:
# ['python', 3.14, True, 'class', 'maham']

# %%
my_list[:3]
# Out:
# [3, 'python', 3.14]

# %%
my_list
# Out:
# [3, 'python', 3.14, True, 'class', 'maham']

# %%
my_list[0:5:1] #it returns immediate next item
# Out:
# [3, 'python', 3.14, True, 'class']

# %%
my_list[0:5:2] #it returns by skiping 1 item -step given as 2
# Out:
# [3, 3.14, 'class']

# %%
my_list[::2]
# Out:
# [3, 3.14, 'class']

# %%
#reverse slicing
my_list[6:1:-1]
# Out:
# ['maham', 'class', True, 3.14]

# %%
my_list[6:1:-2]
# Out:
# ['maham', True]

# %%
#Advance list - lists within list
fruits=['mango','carrot',['melon','lychee','water melon'],'kiwi','banana','orange',['orange','plum']]
fruits
# Out:
# ['mango',
#  'carrot',
#  ['melon', 'lychee', 'water melon'],
#  'kiwi',
#  'banana',
#  'orange',
#  ['orange', 'plum']]

# %%
print(fruits[3]) #at idex 3 of main list is kiwi
# Out:
# kiwi

# %%
fruits[2] #at idex 2 of main list we have another list
# Out:
# ['melon', 'lychee', 'water melon']

# %%
fruits[2][1]  #at index 2 of main list then at index 1 of that within list
# Out:
# 'lychee'

# %%
fruits[2:6]
# Out:
# [['melon', 'lychee', 'water melon'], 'kiwi', 'banana', 'orange']

# %%
fruits
# Out:
# ['mango',
#  'carrot',
#  ['melon', 'lychee', 'water melon'],
#  'kiwi',
#  'banana',
#  'orange',
#  ['orange', 'plum']]

# %%
fruits[-1]
# Out:
# ['orange', 'plum']

# %%
len(fruits)
# Out:
# 7

# %%
#list methods - specific to list class
#append ------takes only 1 argument and adds it in the end
fruits=['mango','apple','banana']
fruits.append('orange')
fruits
# Out:
# ['mango', 'apple', 'banana', 'orange']

# %%
#otherway was
#addition in list
fruits = fruits + ['kiwi']
print(fruits)
# Out:
# ['mango', 'apple', 'banana', 'orange', 'kiwi']

# %%
#Insert method -- adds an element at the specified position-- doesnt overwrites rather drags others
fruits.insert(0,'orange')
fruits
# Out:
# ['orange', 'mango', 'apple', 'banana', 'orange', 'kiwi']

# %%
#modify list  --- overwrites deletes previous
fruits[0]='plum'
fruits
# Out:
# ['plum', 'mango', 'apple', 'banana', 'orange', 'kiwi']

# %%
#extend -used when adding more than 1 items in the list -adds at end
fruits
# Out:
# ['plum', 'mango', 'apple', 'banana', 'orange', 'kiwi']

# %%
fruits.extend(['melon','watermelon'])
#it is not a list added its 2 sep. items added if we want to add a list within list us double square brackets[[]]

# %%
fruits
# Out:
# ['plum', 'mango', 'apple', 'banana', 'orange', 'kiwi', 'melon', 'watermelon']

# %%
fruits.extend([['watermelon','oragne'],['kiwi'],['mango','apple']])

# %%
fruits
# Out:
# ['plum',
#  'mango',
#  'apple',
#  'banana',
#  'orange',
#  'kiwi',
#  'melon',
#  'watermelon',
#  ['watermelon', 'oragne'],
#  ['kiwi'],
#  ['mango', 'apple']]

# %%
#remove method - removes the first instence item with the specified value
fruits
# Out:
# ['plum',
#  'mango',
#  'apple',
#  'banana',
#  'orange',
#  'kiwi',
#  'melon',
#  'watermelon',
#  ['watermelon', 'oragne'],
#  ['kiwi'],
#  ['mango', 'apple']]

# %%
fruits.remove('orange')
fruits
# Out:
# ['plum',
#  'mango',
#  'apple',
#  'banana',
#  'kiwi',
#  'melon',
#  'watermelon',
#  ['watermelon', 'oragne'],
#  ['kiwi'],
#  ['mango', 'apple']]

# %%
#pop method - removes element at the specified position
#fruits.pop(3)
#it removes and also returns the removed item so we can store it.
removed_item = fruits.pop(3)

# %%
removed_item
# Out:
# 'banana'

# %%
#copy method -- returns a copy of the list
#fruits2=fruits -- wrong way to copy one changes other will also change
#so use copy method
fruits2=fruits.copy()

# %%
print(fruits2)
# Out:
# ['plum', 'mango', 'apple', 'kiwi', 'melon', 'watermelon', ['watermelon', 'oragne'], ['kiwi'], ['mango', 'apple']]

# %%
#index method -- returns the index of the first element with sepecified value
fruits.index('apple')
# Out:
# 2

# %%
#other list methods --- clear count reverse

# %% [markdown]
# Strings

# %%
#immutable so to make permanent changes we will need to use assignment operator

# %%
word = 'python'
word[-1]
# Out:
# 'n'

# %%
#word[-1]='L'   #it will give error bcz immutable so use
word =word[:5] + 'L'
word
# Out:
# 'pythoL'

# %%
#String Methods
#replace method    similar as insert method of list but that doesnt dont deletes rather drags remaing items
my_str= 'abcdefghijklmnopqrstuvwxyz'
my_str.replace('c','7')
# Out:
# 'ab7defghijklmnopqrstuvwxyz'

# %%
#original will not change because immutable
my_str
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
my_str=my_str.replace('c','7')
print(my_str)
# Out:
# ab7defghijklmnopqrstuvwxyz

# %%
#index method  -- returns the position of the first occurence
my_str="This is a python class"
my_str.index('is')
# Out:
# 2

# %%
#find method -- same like index -- find will return -1 if string not found and index returns error if not found
my_str.find('sql')
# Out:
# -1

# %%
#other string methods --
my_str.upper()
# Out:
# 'THIS IS A PYTHON CLASS'

# %%
my_str.lower()
# Out:
# 'this is a python class'

# %%
#to check if purely numeric or not
my_str.isnumeric()
# Out:
# False

# %%
my_str.isalpha()  #bcz there are spaces that is why returned false
# Out:
# False

# %%
len(my_str)
len('hello world')
max('hello world')
min('hello world')
sorted('hello world',reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %%
s = 'hello world'
print(s.capitalize())
print(s)
# Out:
# Hello world
# hello world

# %%
s.title()
# Out:
# 'Hello World'

# %%
#'HeLlO WorLD'.swapcase()

# %%
'my name is nitish'.count('i')
# Out:
# 3

# %%
name = 'nitish'
gender = 'male'

'Hi my name is {1} and I am a {0}'.format(gender,name)
# Out:
# 'Hi my name is nitish and I am a male'

# %%
#'hi my name is nitish'.split()
#" ".join(['hi', 'my', 'name', 'is', 'nitish'])
'nitish                           '.strip() #extra spcaes remove
# Out:
# 'nitish'

# %%
#othermethods --- .startswith, .endswith, .digits, .isdigit, .swapcase used to convert lower to upper or vise versa
# .replace .len()

# %%
# Find the length of a given string without using the len() function

s = input('enter the string')

counter = 0

for i in s:
  counter += 1

print('length of string is',counter)
# Out:
# length of string is 15

# %% [markdown]
# Tuples

# %%
# immutable ()
#only one item tuple
my_tup2=('python',) # if only one item then must use ''''  , '''' comma at the end
my_tup2
# Out:
# ('python',)

# %%
my_tup=('mango','orange',3,9,85,'python')
my_tup
# Out:
# ('mango', 'orange', 3, 9, 85, 'python')

# %%
my_tup[1]
# Out:
# 'orange'

# %%
#my_tup[1]='apple'  #it will give error as immutable

# %%
#count method
my_tup.count('mango')
# Out:
# 1

# %%
my_tup.index('orange')
# Out:
# 1

# %% [markdown]
# Dictionaries

# %%
#key-value pairs  -- key should be unique in dic

# %%
grades ={"Hamza":90}
type(grades)
# Out:
# dict

# %%
#indexing
grades={"Hamza":90,"Amna":95,"Abdullah":80,"Azeem":85}
grades
# Out:
# {'Hamza': 90, 'Amna': 95, 'Abdullah': 80, 'Azeem': 85}

# %%
grades["Abdullah"]  #indexing fetching items through key-- we can say these keys are index
# Out:
# 80

# %%
#value change
grades["Hamza"] +=5

# %%
grades
# Out:
# {'Hamza': 95, 'Amna': 95, 'Abdullah': 80, 'Azeem': 85}

# %%
#values as list  -- we can create values as list/dic while key as tuple but not list/dic bcz keys should be unique

# %%
grades2={"Hamza":[90,50,85],"Abdullah":[80,90,5],"Azeem":[85,80,75]}
grades2
# Out:
# {'Hamza': [90, 50, 85], 'Abdullah': [80, 90, 5], 'Azeem': [85, 80, 75]}

# %%
grades2["Azeem"]
# Out:
# [85, 80, 75]

# %%
grades2["Azeem"][1]
# Out:
# 80

# %%
#key as tuple
coordinates={(2,3,4):"Lahore",(5,6,7):"Karachi"}
coordinates
# Out:
# {(2, 3, 4): 'Lahore', (5, 6, 7): 'Karachi'}

# %%
coordinates[(2,3,4)]
# Out:
# 'Lahore'

# %%
#value as dic
grades3={"Hamza":{"english":80,"python":85},"abdullah":{"english":81,"python":79}}
grades3
# Out:
# {'Hamza': {'english': 80, 'python': 85},
#  'abdullah': {'english': 81, 'python': 79}}

# %%
grades3["Hamza"]["english"]
# Out:
# 80

# %%
#make chnages -value change
grades2
# Out:
# {'Hamza': [90, 50, 85], 'Abdullah': [80, 90, 5], 'Azeem': [85, 80, 75]}

# %%
grades2["Hamza"][1]=92
grades2
# Out:
# {'Hamza': [90, 92, 85], 'Abdullah': [80, 90, 5], 'Azeem': [85, 80, 75]}

# %%
#add new entry
grades2["kiran"]=[85,94,79]
grades2
# Out:
# {'Hamza': [90, 92, 85],
#  'Abdullah': [80, 90, 5],
#  'Azeem': [85, 80, 75],
#  'kiran': [85, 94, 79]}
